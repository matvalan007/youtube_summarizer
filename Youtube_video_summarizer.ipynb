# %%
# !pip install youtube_transcript_api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 13.5 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/babthamotharan/rpunct.git (to revision patch-2) to /tmp/pip-req-build-jorvejin
#   Running command git clone --filter=blob:none --quiet https://github.com/babthamotharan/rpunct.git /tmp/pip-req-build-jorvejin
#   Running command git checkout -b patch-2 --track origin/patch-2
#   Switched to a new branch 'patch-2'
#   Branch 'patch-2' set up to track remote branch 'patch-2' from 'origin'.
#   Resolved https://github.com/babthamotharan/rpunct.git to commit a87b93410ca782657abb4e34df9159e6e47ac9ec
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 20.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
  return url_link.split("watch?v=")[-1]

# %%
video_id = get_video_id("https://www.youtube.com/watch?v=gbXQTMWZIp8")

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript
# Out:
# [{'text': 'Hi everyone. So in this video I will be',
#   'start': 0.64,
#   'duration': 3.2},
#  {'text': 'talking about TCS and YouTube results',
#   'start': 2.48,
#   'duration': 4.08},
#  {'text': 'only. But a very important video you can',
#   'start': 3.84,
#   'duration': 4.4},
#  {'text': 'say because there are total three',
#   'start': 6.56,
#   'duration': 4.48},
#  {'text': 'profiles Ninja digital and prime and',
#   'start': 8.24,
#   'duration': 5.6},
#  {'text': 'many candidates are asking me like what',
#   'start': 11.04,
#   'duration': 4.32},
#  {'text': 'will be the parameter of the selections',
#   'start': 13.84,
#   'duration': 3.76},
#  {'text': 'or rejections. First of all I want to',
#   'start': 15.36,
#   'duration': 4.079},
#  {'text': 'something related to the results. First',
#   'start': 17.6,
#   'duration': 5.12},
#  {'text': 'I will clear what all are the things',
#   'start': 19.439,
#   'duration': 5.281},
# ...

# %%
transcript_joined = " ".join([line['text'] for line in transcript])

# %%
transcript_joined
# Out:
# "Hi everyone. So in this video I will be talking about TCS and YouTube results only. But a very important video you can say because there are total three profiles Ninja digital and prime and many candidates are asking me like what will be the parameter of the selections or rejections. First of all I want to something related to the results. First I will clear what all are the things which falls in the category of rejection and suppose if you have given the interview I will be telling you the difference between the ninja digital and prime profile difference the selection difference. Okay so you will get a better idea and the results and uh you will get a clarity that if you can get selected or not. First of all talking about the rejection uh in TCNQ. See first thing I want to tell you is already many rejections many rejections are done. Okay. Now first try to understand how many rejections are done already. Okay. First of all if you have given the assessment if you have okay try to un
# ...

# %%
len(transcript_joined)
# Out:
# 10436

# %%
api_key = ""

# %%
prompt = f'"Answer questions based on: \ntext = "{transcript_joined}. What is the selection scenario for prime candidates?"'

# %%
prompt = f'"Summarize the given text. \ntext = "{transcript_joined}.""'

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-1.5-flash",
    contents=prompt
)
print(response.text)
# Out:
# The selection scenario for prime candidates is highly competitive this year, with far fewer prime profiles offered than last year.  While last year many candidates received prime profiles, this year the number is significantly lower.
#
# If a candidate receives a prime interview, there's a high chance they'll receive a digital profile instead, or even a ninja profile in some cases.  Only about 10-20% of prime interviewees actually receive the prime profile.  The speaker notes that college affiliation seems to play a significant role in prime profile selections, with candidates from reputable colleges (especially NITs or other well-regarded institutions) having a higher chance of selection last year.  They expect fewer demotions from prime to other profiles this year because of the lower number of prime profiles offered.  There is also a luck factor; some candidates received only very short interviews and were demoted regardless of performance.

# %%
len(response.text)
# Out:
# 1213

# %%
def utube_summary(url):
  vedio_id = url.split("watch?v=")[-1]
  transcript = YouTubeTranscriptApi.get_transcript(video_id)
  transcript = " ".join([line['text'] for line in transcript])
  prompt = f'"Summarize the given text. \ntext = "{transcript_joined}.""'
  client = genai.Client(api_key=api_key)

  response = client.models.generate_content(
      model="gemini-1.5-flash",
      contents=prompt
  )
  print(response.text)

# %%
utube_summary("https://www.youtube.com/watch?v=gbXQTMWZIp8")
